# %% [markdown]
# # Metric methods - KNN Classifier

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing

# %%
# Data upload and target/feature split
ml_folder = 'D:\\WORK\ml\\data\\'
wine_data = pd.read_csv(ml_folder+'wine_data.csv', header=None)
classes = wine_data.iloc[:, 0]
features = wine_data.iloc[:, 1:]

# %%
# Prepare cross-validation folds generator
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Import utils notebook

# %%
# %%capture 
# %run nihil_ml_utils.ipynb

# %%
k_values = range(1, 51)

# %%
# Cross-validate on riginal features
accuracy = cross_validate_est(KNeighborsClassifier, features, classes, 
                              kf, k_values, 'n_neighbors')
accuracy
# Out:
#                                                       accuracy      mean
# n_neighbors
# 1            [0.777777777778, 0.666666666667, 0.72222222222...  0.730476
# 34           [0.833333333333, 0.611111111111, 0.75, 0.68571...  0.724603
# 35           [0.805555555556, 0.666666666667, 0.72222222222...  0.724603
# 48           [0.833333333333, 0.611111111111, 0.72222222222...  0.719048
# 36           [0.833333333333, 0.611111111111, 0.69444444444...  0.713492
# 38           [0.805555555556, 0.611111111111, 0.72222222222...  0.713492
# 32           [0.805555555556, 0.611111111111, 0.72222222222...  0.713492
# 33           [0.777777777778, 0.611111111111, 0.75, 0.68571...  0.713492
# 37           [0.805555555556, 0.611111111111, 0.72222222222...  0.713492
# 29           [0.777777777778, 0.638888888889, 0.72222222222...  0.713492
# 41           [0.805555555556, 0.611111111111, 0.72222222222...  0.713492
# 3            [0.805555555556, 0.611111111111, 0.63888888888...  0.708254
# ...

# %%
# Cross-validate on scaled features case
f_scaled = preprocessing.scale(features)
acc_scaled = cross_validate_est(KNeighborsClassifier, f_scaled, classes, 
                              kf, k_values, 'n_neighbors')
acc_scaled
# Out:
#                                                       accuracy      mean
# n_neighbors
# 29           [1.0, 0.944444444444, 0.972222222222, 0.971428...  0.977619
# 16           [0.972222222222, 0.944444444444, 0.97222222222...  0.972063
# 15           [0.972222222222, 0.944444444444, 0.97222222222...  0.972063
# 17           [0.972222222222, 0.916666666667, 0.97222222222...  0.966508
# 20           [0.972222222222, 0.916666666667, 0.97222222222...  0.966508
# 22           [0.944444444444, 0.944444444444, 0.97222222222...  0.966508
# 18           [0.972222222222, 0.916666666667, 0.97222222222...  0.966508
# 28           [0.972222222222, 0.944444444444, 0.97222222222...  0.966349
# 41           [1.0, 0.916666666667, 0.972222222222, 0.971428...  0.966349
# 33           [1.0, 0.916666666667, 0.972222222222, 0.971428...  0.966349
# 34           [1.0, 0.916666666667, 0.972222222222, 0.971428...  0.966349
# 14           [0.972222222222, 0.944444444444, 0.97222222222...  0.966349
# ...
