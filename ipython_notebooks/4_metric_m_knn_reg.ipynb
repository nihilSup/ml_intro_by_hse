# %% [markdown]
# # Metric methods - KNN Regression

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn import preprocessing
from sklearn.model_selection import KFold, cross_val_score
from sklearn.neighbors import KNeighborsRegressor

# %%
# Import utils notebook

# %%
# %%capture 
# %run nihil_ml_utils.ipynb

# %%
# Feature extraction and preprocessing
bunch = datasets.load_boston()
features_scaled = preprocessing.scale(bunch['data'])
y = bunch['target']

# %%
# Prepare range of parameter to variate
p_values = np.linspace(1, 10, num=200)
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Cross-validate estimator KNeighborsRegressor on normalized features and
# variate p parameter for Minkowski metric
res = cross_validate_est(KNeighborsRegressor, features_scaled, y, kf,
                          p_values, 'p', scoring='neg_mean_squared_error',
                          est_params={'weights': 'distance'}, agg_f=np.max)
res
# Out:
#                                       neg_mean_squared_error       amax
# p
# 1.135678   [-20.2917224604, -12.9623694421, -17.661728116... -11.836924
# 1.090452   [-20.2182649726, -12.6557038515, -17.691038502... -11.844383
# 1.180905   [-19.9445536156, -12.9023966511, -18.024136516... -11.876076
# 1.000000   [-20.3004662658, -12.496548295, -17.224727761,... -11.878542
# 1.045226   [-20.309361361, -12.5751809493, -17.4398902289... -11.996570
# 1.271357   [-19.936291512, -13.2445186, -17.9804708246, -... -12.019038
# 1.226131   [-19.8157437494, -12.8755219886, -17.940732959... -12.035631
# 1.407035   [-19.8227108016, -13.9858073323, -19.200864150... -12.581176
# 1.316583   [-19.8526053352, -13.8079289449, -17.687440932... -12.591107
# 1.361809   [-19.8392356781, -13.9394555662, -17.889834720... -12.601727
# 1.452261   [-19.8694291802, -13.6955441991, -19.074449586... -12.897805
# 1.497487   [-19.8030090957, -13.7762265558, -19.022864608... -12.932248
# ...
